# %%
import sys
sys.path.append(".")

# %%
import numpy as np
import glob
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB3
import matplotlib.pylab as plt
from pathlib import Path
from tensorflow.keras import layers
import datetime

# %%
model_name_it = "Outputs/Efficient_net_B0_it_52123.h5"

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 20)

# %%
monitor_it = tf.keras.callbacks.ModelCheckpoint(model_name_it, monitor='val_loss',\
                                             verbose=1,save_best_only=True,\
                                             save_weights_only=False,\
                                             mode='min')

# %%
def scheduler(epoch, lr):
    if epoch%30 == 0 and epoch!= 0:
        lr = lr/2
    return lr

# %%
lr_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler,verbose = 0)

# %%
#%load_ext tensorboard

# %%
#log_dir = "Outputs/logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
#tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
gen_params = {"featurewise_center":False,\
              "samplewise_center":False,\
              "featurewise_std_normalization":False,\
              "samplewise_std_normalization":False,\
              "rotation_range":180,\
              "width_shift_range":0.3,\
              "height_shift_range":0.3, \
              "shear_range":0.3, \
              "zoom_range":0.3,\
              "vertical_flip":True, \
              "brightness_range": (0.2, 2)}

# %%
generator = ImageDataGenerator(**gen_params, validation_split=0.2,  preprocessing_function = tf.keras.applications.efficientnet.preprocess_input)

# %%
bs = 16 # batch size

# %%
path = Path("../dataset/")

# %%
img_height = 224 #B0
img_width = 224 #B0

# %%
classes_names = ["2_clubs","2_diamonds","2_hearts","2_spades",\
               "3_clubs","3_diamonds","3_hearts","3_spades",\
               "4_clubs","4_diamonds","4_hearts","4_spades",\
               "5_clubs","5_diamonds","5_hearts","5_spades",\
               "6_clubs","6_diamonds","6_hearts","6_spades",\
               "7_clubs","7_diamonds","7_hearts","7_spades",\
               "8_clubs","8_diamonds","8_hearts","8_spades",\
               "9_clubs","9_diamonds","9_hearts","9_spades",\
               "10_clubs","10_diamonds","10_hearts","10_spades",\
               "ace_clubs","ace_diamonds","ace_hearts","ace_spades",\
               "jack_clubs","jack_diamonds","jack_hearts","jack_spades",\
               "king_clubs","king_diamonds","king_hearts","king_spades",\
               "queen_clubs","queen_diamonds","queen_hearts","queen_spades"]

# %%
train_generator = generator.flow_from_directory(
    directory = path,
    target_size=(img_height, img_width),
    batch_size=bs,
    class_mode="categorical",
    subset='training',
    shuffle = True,
    interpolation="nearest",
    seed=42,
    classes=classes_names) # set as training data
# Out:
# Found 24952 images belonging to 52 classes.

# %%
validation_generator = generator.flow_from_directory(
    directory = path,
    target_size=(img_height, img_width),
    batch_size=bs,
    class_mode="categorical",
    subset='validation',
    interpolation="nearest",
    seed=42,
    classes=classes_names) # set as validation data
# Out:
# Found 6206 images belonging to 52 classes.

# %%
#Exploratory data analysis
plt.figure(figsize = (32,24))
Xbatch,Ybatch = train_generator.__getitem__(0)

for ii in range(int(bs)):
    plt.subplot(4,4,ii+1)
    plt.imshow((Xbatch[ii]- Xbatch[ii].min())/(Xbatch.max() - Xbatch[ii].min()), cmap = "gray")
    class_idx = int(Ybatch[ii].argmax())
    plt.title("Label: {}".format(classes_names[class_idx]), fontsize=25)
plt.show()

# %%
# Defining the model

trainable_flag = True
include_top_flag = False
weigths_value = 'imagenet'

if trainable_flag:
    include_top_flag = True
    weigths_value = None
else:
    include_top_flag = False
    weigths_value = 'imagenet'

# %%
print(weigths_value)
print(include_top_flag)
print(trainable_flag)
# Out:
# None
# True
# True

# %%
inputs = layers.Input(shape=(img_height,img_width,3))
outputs = tf.keras.applications.EfficientNetB0(include_top=include_top_flag, weights=weigths_value,drop_connect_rate=0.3, classes=len(classes_names))(inputs)
model = tf.keras.Model(inputs,  outputs)

# %%
print("Initial Training Model")
print(model.summary())
# Out:
# Initial Training Model
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  efficientnetb0 (Functional)  (None, 52)               4116183
#
# =================================================================
# Total params: 4,116,183
# Trainable params: 4,074,160
# Non-trainable params: 42,023
# _________________________________________________________________
# None

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 1e-3), #
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#model = tf.keras.models.load_model('BEST_MODEL_B0/EfficientNetB0_52_96_percent_last_model.h5')
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  efficientnetb0 (Functional)  (None, 52)               4116183
#
# =================================================================
# Total params: 4,116,183
# Trainable params: 4,074,160
# Non-trainable params: 42,023
# _________________________________________________________________

# %%
history_it = model.fit(train_generator, epochs=1000, verbose = 1, \
                       workers=8, validation_data = (validation_generator), callbacks= [monitor_it,early_stop,lr_schedule])
# Out:
# Epoch 1/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 3.3107 - accuracy: 0.0955
# Epoch 1: val_loss improved from inf to 3.17742, saving model to Outputs\Efficient_net_B0_it_52123.h5
# 1560/1560 [==============================] - 402s 253ms/step - loss: 3.3107 - accuracy: 0.0955 - val_loss: 3.1774 - val_accuracy: 0.0964 - lr: 0.0010
# Epoch 2/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 2.1549 - accuracy: 0.2936
# Epoch 2: val_loss improved from 3.17742 to 2.30469, saving model to Outputs\Efficient_net_B0_it_52123.h5
# 1560/1560 [==============================] - 392s 252ms/step - loss: 2.1549 - accuracy: 0.2936 - val_loss: 2.3047 - val_accuracy: 0.2204 - lr: 0.0010
# Epoch 3/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 1.5134 - accuracy: 0.4876
# Epoch 3: val_loss improved from 2.30469 to 2.14295, saving model to Outputs\Efficient_net_B0_it_52123.h5
# 1560/1560 [==============================] - 391s 250ms/step - loss: 1.5134 - accuracy: 0.4876 - val_loss: 2.1429 - val_accuracy: 0.2717 - lr: 0.0010
# Epoch 4/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 1.1206 - accuracy: 0.6214
# Epoch 4: val_loss improved from 2.14295 to 1.75897, saving model to Outputs\Efficient_net_B0_it_52123.h5
# 1560/1560 [==============================] - 392s 252ms/step - loss: 1.1206 - accuracy: 0.6214 - val_loss: 1.7590 - val_accuracy: 0.4075 - lr: 0.0010
# Epoch 5/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.8544 - accuracy: 0.7125
# Epoch 5: val_loss improved from 1.75897 to 1.54704, saving model to Outputs\Efficient_net_B0_it_52123.h5
# 1560/1560 [==============================] - 390s 250ms/step - loss: 0.8544 - accuracy: 0.7125 - val_loss: 1.5470 - val_accuracy: 0.4955 - lr: 0.0010
# Epoch 6/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.6655 - accuracy: 0.7775
# Epoch 6: val_loss did not improve from 1.54704
# 1560/1560 [==============================] - 389s 250ms/step - loss: 0.6655 - accuracy: 0.7775 - val_loss: 1.5874 - val_accuracy: 0.5166 - lr: 0.0010
# Epoch 7/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.5496 - accuracy: 0.8154
# Epoch 7: val_loss improved from 1.54704 to 1.23812, saving model to Outputs\Efficient_net_B0_it_52123.h5
# 1560/1560 [==============================] - 390s 250ms/step - loss: 0.5496 - accuracy: 0.8154 - val_loss: 1.2381 - val_accuracy: 0.5811 - lr: 0.0010
# Epoch 8/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.4483 - accuracy: 0.8498
# Epoch 8: val_loss did not improve from 1.23812
# 1560/1560 [==============================] - 390s 250ms/step - loss: 0.4483 - accuracy: 0.8498 - val_loss: 1.3288 - val_accuracy: 0.6023 - lr: 0.0010
# Epoch 9/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.3786 - accuracy: 0.8734
# Epoch 9: val_loss did not improve from 1.23812
# 1560/1560 [==============================] - 390s 250ms/step - loss: 0.3786 - accuracy: 0.8734 - val_loss: 1.4472 - val_accuracy: 0.6005 - lr: 0.0010
# Epoch 10/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.3347 - accuracy: 0.8883
# Epoch 10: val_loss did not improve from 1.23812
# 1560/1560 [==============================] - 390s 250ms/step - loss: 0.3347 - accuracy: 0.8883 - val_loss: 1.4073 - val_accuracy: 0.6144 - lr: 0.0010
# Epoch 11/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.2881 - accuracy: 0.9051
# Epoch 11: val_loss improved from 1.23812 to 1.16931, saving model to Outputs\Efficient_net_B0_it_52123.h5
# 1560/1560 [==============================] - 390s 250ms/step - loss: 0.2881 - accuracy: 0.9051 - val_loss: 1.1693 - val_accuracy: 0.6806 - lr: 0.0010
# Epoch 12/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.2516 - accuracy: 0.9168
# Epoch 12: val_loss did not improve from 1.16931
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.2516 - accuracy: 0.9168 - val_loss: 1.2265 - val_accuracy: 0.6610 - lr: 0.0010
# Epoch 13/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9241
# Epoch 13: val_loss improved from 1.16931 to 1.05283, saving model to Outputs\Efficient_net_B0_it_52123.h5
# 1560/1560 [==============================] - 390s 250ms/step - loss: 0.2304 - accuracy: 0.9241 - val_loss: 1.0528 - val_accuracy: 0.7164 - lr: 0.0010
# Epoch 14/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.2030 - accuracy: 0.9336
# Epoch 14: val_loss did not improve from 1.05283
# 1560/1560 [==============================] - 389s 250ms/step - loss: 0.2030 - accuracy: 0.9336 - val_loss: 1.0728 - val_accuracy: 0.7283 - lr: 0.0010
# Epoch 15/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.1907 - accuracy: 0.9388
# Epoch 15: val_loss did not improve from 1.05283
# 1560/1560 [==============================] - 389s 250ms/step - loss: 0.1907 - accuracy: 0.9388 - val_loss: 1.2525 - val_accuracy: 0.7017 - lr: 0.0010
# Epoch 16/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.1804 - accuracy: 0.9388
# Epoch 16: val_loss did not improve from 1.05283
# 1560/1560 [==============================] - 392s 251ms/step - loss: 0.1804 - accuracy: 0.9388 - val_loss: 1.1174 - val_accuracy: 0.7148 - lr: 0.0010
# Epoch 17/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.1514 - accuracy: 0.9500
# Epoch 17: val_loss did not improve from 1.05283
# 1560/1560 [==============================] - 396s 254ms/step - loss: 0.1514 - accuracy: 0.9500 - val_loss: 1.1788 - val_accuracy: 0.7043 - lr: 0.0010
# Epoch 18/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.1559 - accuracy: 0.9504
# Epoch 18: val_loss did not improve from 1.05283
# 1560/1560 [==============================] - 395s 253ms/step - loss: 0.1559 - accuracy: 0.9504 - val_loss: 1.2649 - val_accuracy: 0.6916 - lr: 0.0010
# Epoch 19/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9528
# Epoch 19: val_loss did not improve from 1.05283
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.1425 - accuracy: 0.9528 - val_loss: 1.2115 - val_accuracy: 0.7124 - lr: 0.0010
# Epoch 20/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9554
# Epoch 20: val_loss improved from 1.05283 to 0.98976, saving model to Outputs\Efficient_net_B0_it_52123.h5
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.1349 - accuracy: 0.9554 - val_loss: 0.9898 - val_accuracy: 0.7585 - lr: 0.0010
# Epoch 21/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.1201 - accuracy: 0.9615
# Epoch 21: val_loss improved from 0.98976 to 0.96306, saving model to Outputs\Efficient_net_B0_it_52123.h5
# 1560/1560 [==============================] - 389s 250ms/step - loss: 0.1201 - accuracy: 0.9615 - val_loss: 0.9631 - val_accuracy: 0.7723 - lr: 0.0010
# Epoch 22/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.1238 - accuracy: 0.9592
# Epoch 22: val_loss did not improve from 0.96306
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.1238 - accuracy: 0.9592 - val_loss: 1.1468 - val_accuracy: 0.7404 - lr: 0.0010
# Epoch 23/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.1122 - accuracy: 0.9641
# Epoch 23: val_loss did not improve from 0.96306
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.1122 - accuracy: 0.9641 - val_loss: 1.1400 - val_accuracy: 0.7312 - lr: 0.0010
# Epoch 24/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9637
# Epoch 24: val_loss did not improve from 0.96306
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.1125 - accuracy: 0.9637 - val_loss: 0.9786 - val_accuracy: 0.7710 - lr: 0.0010
# Epoch 25/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.1036 - accuracy: 0.9670
# Epoch 25: val_loss did not improve from 0.96306
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.1036 - accuracy: 0.9670 - val_loss: 1.0930 - val_accuracy: 0.7594 - lr: 0.0010
# Epoch 26/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.1025 - accuracy: 0.9661
# Epoch 26: val_loss did not improve from 0.96306
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.1025 - accuracy: 0.9661 - val_loss: 1.0677 - val_accuracy: 0.7556 - lr: 0.0010
# Epoch 27/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0900 - accuracy: 0.9723
# Epoch 27: val_loss did not improve from 0.96306
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0900 - accuracy: 0.9723 - val_loss: 1.1884 - val_accuracy: 0.7404 - lr: 0.0010
# Epoch 28/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9678
# Epoch 28: val_loss did not improve from 0.96306
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0989 - accuracy: 0.9678 - val_loss: 1.0206 - val_accuracy: 0.7733 - lr: 0.0010
# Epoch 29/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0790 - accuracy: 0.9753
# Epoch 29: val_loss did not improve from 0.96306
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0790 - accuracy: 0.9753 - val_loss: 1.2668 - val_accuracy: 0.7386 - lr: 0.0010
# Epoch 30/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0893 - accuracy: 0.9715
# Epoch 30: val_loss did not improve from 0.96306
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0893 - accuracy: 0.9715 - val_loss: 1.1413 - val_accuracy: 0.7578 - lr: 0.0010
# Epoch 31/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0356 - accuracy: 0.9895
# Epoch 31: val_loss improved from 0.96306 to 0.79902, saving model to Outputs\Efficient_net_B0_it_52123.h5
# 1560/1560 [==============================] - 390s 250ms/step - loss: 0.0356 - accuracy: 0.9895 - val_loss: 0.7990 - val_accuracy: 0.8284 - lr: 5.0000e-04
# Epoch 32/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9929
# Epoch 32: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0254 - accuracy: 0.9929 - val_loss: 0.9073 - val_accuracy: 0.8053 - lr: 5.0000e-04
# Epoch 33/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9928
# Epoch 33: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0253 - accuracy: 0.9928 - val_loss: 0.8954 - val_accuracy: 0.8271 - lr: 5.0000e-04
# Epoch 34/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9907
# Epoch 34: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0283 - accuracy: 0.9907 - val_loss: 0.9039 - val_accuracy: 0.8105 - lr: 5.0000e-04
# Epoch 35/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9927
# Epoch 35: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0228 - accuracy: 0.9927 - val_loss: 0.9116 - val_accuracy: 0.8266 - lr: 5.0000e-04
# Epoch 36/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9915
# Epoch 36: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 388s 249ms/step - loss: 0.0255 - accuracy: 0.9915 - val_loss: 0.9104 - val_accuracy: 0.8163 - lr: 5.0000e-04
# Epoch 37/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9933
# Epoch 37: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0225 - accuracy: 0.9933 - val_loss: 1.0417 - val_accuracy: 0.8021 - lr: 5.0000e-04
# Epoch 38/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 0.9933
# Epoch 38: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0219 - accuracy: 0.9933 - val_loss: 0.9473 - val_accuracy: 0.8226 - lr: 5.0000e-04
# Epoch 39/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9922
# Epoch 39: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0257 - accuracy: 0.9922 - val_loss: 1.0316 - val_accuracy: 0.8018 - lr: 5.0000e-04
# Epoch 40/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9936
# Epoch 40: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0213 - accuracy: 0.9936 - val_loss: 0.9635 - val_accuracy: 0.8105 - lr: 5.0000e-04
# Epoch 41/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9926
# Epoch 41: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0245 - accuracy: 0.9926 - val_loss: 0.9311 - val_accuracy: 0.8213 - lr: 5.0000e-04
# Epoch 42/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9943
# Epoch 42: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0187 - accuracy: 0.9943 - val_loss: 0.9104 - val_accuracy: 0.8274 - lr: 5.0000e-04
# Epoch 43/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9941
# Epoch 43: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0205 - accuracy: 0.9941 - val_loss: 0.9757 - val_accuracy: 0.8158 - lr: 5.0000e-04
# Epoch 44/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9919
# Epoch 44: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0255 - accuracy: 0.9919 - val_loss: 0.9901 - val_accuracy: 0.8165 - lr: 5.0000e-04
# Epoch 45/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9928
# Epoch 45: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0229 - accuracy: 0.9928 - val_loss: 1.0820 - val_accuracy: 0.8081 - lr: 5.0000e-04
# Epoch 46/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9943
# Epoch 46: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0202 - accuracy: 0.9943 - val_loss: 0.9967 - val_accuracy: 0.8110 - lr: 5.0000e-04
# Epoch 47/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9947
# Epoch 47: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 388s 249ms/step - loss: 0.0192 - accuracy: 0.9947 - val_loss: 1.0552 - val_accuracy: 0.8107 - lr: 5.0000e-04
# Epoch 48/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9928
# Epoch 48: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0234 - accuracy: 0.9928 - val_loss: 0.9816 - val_accuracy: 0.8086 - lr: 5.0000e-04
# Epoch 49/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9936
# Epoch 49: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0207 - accuracy: 0.9936 - val_loss: 0.9904 - val_accuracy: 0.8147 - lr: 5.0000e-04
# Epoch 50/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9942
# Epoch 50: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0179 - accuracy: 0.9942 - val_loss: 0.9175 - val_accuracy: 0.8257 - lr: 5.0000e-04
# Epoch 51/1000
# 1560/1560 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9943
# Epoch 51: val_loss did not improve from 0.79902
# 1560/1560 [==============================] - 389s 249ms/step - loss: 0.0195 - accuracy: 0.9943 - val_loss: 1.0329 - val_accuracy: 0.8147 - lr: 5.0000e-04

# %%
model.save('Outputs/Efficient_net_B0_it_52_no_aug_last_model.h5')
np.save('Outputs/Efficient_net_B0_it_52_no_aug.npy',history_it.history)

# %%
# list all data in history
print(chistory_it.keys())
# summarize history for accuracy
plt.plot(history_it['accuracy'])
plt.plot(history_it['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history_it['loss'])
plt.plot(history_it['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
